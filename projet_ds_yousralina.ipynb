# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
url = 'https://raw.githubusercontent.com/yousralinael/projet_python_ds/main/Prix%20panier.csv?token=GHSAT0AAAAAAB4GOA3TAF6NQE6Y2DL4WWV2Y4XW4DQ'
df=pd.read_csv(url, sep=";") #base de données principales
df.head()
df1=df.drop('Indicateur', axis=1, inplace=False)
df2=df1.transpose()
df2.columns= df2.iloc[0]
df3=df2.drop(df2.index[0])
df4=df2.assign(key=[i for i in range(217)])
df4
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-9624f41bf54e> in <module>
#       1 url = 'https://raw.githubusercontent.com/yousralinael/projet_python_ds/main/Prix%20panier.csv?token=GHSAT0AAAAAAB4GOA3TAF6NQE6Y2DL4WWV2Y4XW4DQ'
# ----> 2 df=pd.read_csv(url, sep=";") #base de données principales
#       3 df.head()
#       4 df1=df.drop('Indicateur', axis=1, inplace=False)
#       5 df2=df1.transpose()
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
url2 = 'https://raw.githubusercontent.com/yousralinael/projet_python_ds/main/ipc_.csv?token=GHSAT0AAAAAAB4GOA3SY7QPYBYEQ55GHZJMY4XXAOQ'
ipc=pd.read_csv(url2, sep=";") #bases de données avec l'indice des prix à la vente
ipc1=ipc.assign(key=[i for i in range(216)])

# %%
dff=df4.merge(ipc1, on="key")
dff1=dff.drop(["Periode"], axis=1)
dff1
# Out:
#      Steak hache  Pains et cereales : pates superieures  Emmental francais  \
# 0    Steak hache  Pains et cereales : pates superieures  Emmental francais
# 1         16,744                                   5,84              3,232
# 2         16,744                                   5,84               3,24
# 3         16,629                                   5,84              3,224
# 4          16,79                                   5,92              3,248
# ..           ...                                    ...                ...
# 211       27,002                                   6,24              3,448
# 212       27,002                                   6,24              3,448
# 213       27,048                                   6,16              3,448
# 214       27,163                                   6,16               3,44
# 215       27,186                                   6,16              3,444
#
# ...

# %%
url3="https://raw.githubusercontent.com/yousralinael/projet_python_ds/main/ipp.csv?token=GHSAT0AAAAAAB4GOA3SZPEYDNKF46OZ7RC6Y47EGJA"
ipp=ipc=pd.read_csv(url3, sep=";") #bases de données avec l'indice des prix à la production
ipc1=ipc.assign(key=[i for i in range(216)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b966b6c98980> in <module>
#       1 url3="https://raw.githubusercontent.com/yousralinael/projet_python_ds/main/ipp.csv?token=GHSAT0AAAAAAB4GOA3SZPEYDNKF46OZ7RC6Y47EGJA"
# ----> 2 ipp=ipc=pd.read_csv(url3, sep=";") #bases de données avec l'indice des prix à la production
#       3 ipc1=ipc.assign(key=[i for i in range(216)])
#
# NameError: name 'pd' is not defined
